# %% [markdown]
# <a href="https://colab.research.google.com/github/akkkiii08/FMML_Projects-and-labs/blob/main/Module9_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module 9: Neural Networks
#
# Lab 2: Using MLP for multiclass classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the iris dataset
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# MLP for multiclass classification

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm

# %%
# Defining the model architecture
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Instantiating the model, using Adam optimiser, and Cross Entropy Loss, which is quite commonlu used for classification tasks.
model     = Model(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()

# %% [markdown]
# Train the model

# %%
# Train for 100 epochs
EPOCHS  = 100
X_train = torch.from_numpy(X_train).float()
X_test= torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test)
y_train = torch.from_numpy(y_train)


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 350.87it/s]

# %% [markdown]
# Plot training progress

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");

# %% [markdown]
# Experiment with the neural network architecture
#
# 1)Try changing the number of hidden layers.
#
# 2)Try changing the number of neurons in the hidden layer.
#
# 3)Try using a different activation function.
# Can you observe any changes?

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, activations
from tensorflow.keras.datasets import mnist

# Load and preprocess the data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Base Model
def create_base_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 1: Change the number of hidden layers
def create_model_exp1(num_hidden_layers):
    model = models.Sequential()
    model.add(layers.Flatten(input_shape=(28, 28)))
    for _ in range(num_hidden_layers):
        model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    return model

# Experiment 2: Change the number of neurons in the hidden layer
def create_model_exp2(num_neurons):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(num_neurons, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 3: Use a different activation function
def create_model_exp3(activation_func):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation=activation_func),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Train and evaluate a given model
def train_and_evaluate(model):
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.fit(train_images, train_labels, epochs=5, validation_data=(test_images, test_labels))

# Base Model
print("Base Model:")
base_model = create_base_model()
train_and_evaluate(base_model)

# Experiment 1: Change the number of hidden layers
print("\nExperiment 1: Change the number of hidden layers")
for num_hidden_layers in [1, 2, 3]:
    print(f"\nNumber of hidden layers: {num_hidden_layers}")
    model_exp1 = create_model_exp1(num_hidden_layers)
    train_and_evaluate(model_exp1)

# Experiment 2: Change the number of neurons in the hidden layer
print("\nExperiment 2: Change the number of neurons in the hidden layer")
for num_neurons in [64, 128, 256]:
    print(f"\nNumber of neurons in the hidden layer: {num_neurons}")
    model_exp2 = create_model_exp2(num_neurons)
    train_and_evaluate(model_exp2)

# Experiment 3: Use a different activation function
print("\nExperiment 3: Use a different activation function")
activation_functions = ['relu', 'tanh', 'sigmoid']
for activation_func in activation_functions:
    print(f"\nActivation function: {activation_func}")
    model_exp3 = create_model_exp3(activation_func)
    train_and_evaluate(model_exp3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Base Model:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2562 - accuracy: 0.9272 - val_loss: 0.1300 - val_accuracy: 0.9604
# Epoch 2/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1097 - accuracy: 0.9677 - val_loss: 0.1034 - val_accuracy: 0.9693
# Epoch 3/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0752 - accuracy: 0.9772 - val_loss: 0.0880 - val_accuracy: 0.9725
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0561 - accuracy: 0.9828 - val_loss: 0.0800 - val_accuracy: 0.9745
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0430 - accuracy: 0.9868 - val_loss: 0.0794 - val_accuracy: 0.9755
#
# Experiment 1: Change the number of hidden layers
#
# Number of hidden layers: 1
# Epoch 1/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2602 - accuracy: 0.9261 - val_loss: 0.1420 - val_accuracy: 0.9581
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1168 - accuracy: 0.9657 - val_loss: 0.0999 - val_accuracy: 0.9692
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0787 - accuracy: 0.9763 - val_loss: 0.0886 - val_accuracy: 0.9731
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0597 - accuracy: 0.9822 - val_loss: 0.0848 - val_accuracy: 0.9745
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0473 - accuracy: 0.9852 - val_loss: 0.0769 - val_accuracy: 0.9764
#
# Number of hidden layers: 2
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2315 - accuracy: 0.9316 - val_loss: 0.1210 - val_accuracy: 0.9631
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0987 - accuracy: 0.9696 - val_loss: 0.0914 - val_accuracy: 0.9727
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0709 - accuracy: 0.9776 - val_loss: 0.0892 - val_accuracy: 0.9735
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0524 - accuracy: 0.9826 - val_loss: 0.0961 - val_accuracy: 0.9709
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0410 - accuracy: 0.9867 - val_loss: 0.0841 - val_accuracy: 0.9755
#
# Number of hidden layers: 3
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2258 - accuracy: 0.9322 - val_loss: 0.1117 - val_accuracy: 0.9660
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0979 - accuracy: 0.9698 - val_loss: 0.0856 - val_accuracy: 0.9720
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0706 - accuracy: 0.9777 - val_loss: 0.0905 - val_accuracy: 0.9731
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0543 - accuracy: 0.9826 - val_loss: 0.0963 - val_accuracy: 0.9730
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0471 - accuracy: 0.9849 - val_loss: 0.0755 - val_accuracy: 0.9784
#
# Experiment 2: Change the number of neurons in the hidden layer
#
# Number of neurons in the hidden layer: 64
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3058 - accuracy: 0.9128 - val_loss: 0.1864 - val_accuracy: 0.9439
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1491 - accuracy: 0.9569 - val_loss: 0.1227 - val_accuracy: 0.9640
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1097 - accuracy: 0.9680 - val_loss: 0.1094 - val_accuracy: 0.9691
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0866 - accuracy: 0.9744 - val_loss: 0.0925 - val_accuracy: 0.9732
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0715 - accuracy: 0.9785 - val_loss: 0.0910 - val_accuracy: 0.9724
#
# Number of neurons in the hidden layer: 128
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2548 - accuracy: 0.9267 - val_loss: 0.1356 - val_accuracy: 0.9599
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1102 - accuracy: 0.9674 - val_loss: 0.0930 - val_accuracy: 0.9712
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0764 - accuracy: 0.9769 - val_loss: 0.0884 - val_accuracy: 0.9724
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0575 - accuracy: 0.9820 - val_loss: 0.0851 - val_accuracy: 0.9750
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0446 - accuracy: 0.9859 - val_loss: 0.0711 - val_accuracy: 0.9778
#
# Number of neurons in the hidden layer: 256
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2250 - accuracy: 0.9354 - val_loss: 0.1347 - val_accuracy: 0.9598
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0934 - accuracy: 0.9715 - val_loss: 0.0902 - val_accuracy: 0.9732
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0630 - accuracy: 0.9808 - val_loss: 0.0755 - val_accuracy: 0.9768
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0443 - accuracy: 0.9868 - val_loss: 0.0688 - val_accuracy: 0.9779
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0328 - accuracy: 0.9891 - val_loss: 0.0792 - val_accuracy: 0.9768
#
# Experiment 3: Use a different activation function
#
# Activation function: relu
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2549 - accuracy: 0.9280 - val_loss: 0.1425 - val_accuracy: 0.9575
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1126 - accuracy: 0.9670 - val_loss: 0.0974 - val_accuracy: 0.9703
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0769 - accuracy: 0.9761 - val_loss: 0.0820 - val_accuracy: 0.9754
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0577 - accuracy: 0.9821 - val_loss: 0.0821 - val_accuracy: 0.9758
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0441 - accuracy: 0.9865 - val_loss: 0.0731 - val_accuracy: 0.9774
#
# Activation function: tanh
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2868 - accuracy: 0.9169 - val_loss: 0.1697 - val_accuracy: 0.9522
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1388 - accuracy: 0.9600 - val_loss: 0.1144 - val_accuracy: 0.9672
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0940 - accuracy: 0.9727 - val_loss: 0.0942 - val_accuracy: 0.9715
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0679 - accuracy: 0.9799 - val_loss: 0.0844 - val_accuracy: 0.9735
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0525 - accuracy: 0.9844 - val_loss: 0.0788 - val_accuracy: 0.9754
#
# Activation function: sigmoid
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3988 - accuracy: 0.8960 - val_loss: 0.2272 - val_accuracy: 0.9346
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1962 - accuracy: 0.9438 - val_loss: 0.1643 - val_accuracy: 0.9514
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1440 - accuracy: 0.9583 - val_loss: 0.1297 - val_accuracy: 0.9616
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1122 - accuracy: 0.9680 - val_loss: 0.1099 - val_accuracy: 0.9667
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0901 - accuracy: 0.9743 - val_loss: 0.0973 - val_accuracy: 0.9697
